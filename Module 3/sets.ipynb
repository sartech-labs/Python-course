# %%
s = {1, 2,2, 3}
print(s)
# Out:
# {1, 2, 3}

# %%
s.add(5)

# %%
print(s)
# Out:
# {1, 2, 3, 5}

# %%
s.add(3)
print(s)
# Out:
# {1, 2, 3, 5}

# %%
s2 = {3,7,9}
print(s2)
# Out:
# {9, 3, 7}

# %%
s3 = s.union(s2)
print(s3)
# Out:
# {1, 2, 3, 5, 7, 9}

# %%
s4 = s.intersection(s2)
print(s4)
# Out:
# {3}

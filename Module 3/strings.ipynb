# %%
name = "Rebecca"
print(name)
# Out:
# Rebecca

# %%
print(name.upper())
# Out:
# REBECCA

# %%
print(name.lower())
# Out:
# rebecca

# %%
name
# Out:
# 'Rebecca'

# %%
print(name[0])
# Out:
# R

# %%
print(name[0:3])
# Out:
# Reb

# %%
len(name)
# Out:
# 7

# %%
print(name[0:7])
# Out:
# Rebecca

# %%
print(name[3: 6])
# Out:
# ecc

# %%
sentence = 'i love python'

# %%
sentence
# Out:
# 'i love python'

# %%
words = sentence.split(' ')
print(words)
# Out:
# ['i', 'love', 'python']

# %%
sen = 'hi, hello, how are you?'
wrds = sen.split(',')
print(wrds)
# Out:
# ['hi', ' hello', ' how are you?']

# %%
line = 'Fake python'
print(line)
# Out:
# Fake python

# %%
print(line.replace('Fake', 'Real'))
# Out:
# Real python

# %%
student = {'name': 'Ash', 'age': 25}
print(student)
# Out:
# {'name': 'Ash', 'age': 25}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
student.items()
# Out:
# dict_items([('name', 'Ash'), ('age', 25)])

# %%
for k, v in student.items():
    print(f"{k}={v}")
# Out:
# name=Ash
# age=25

# %%
student['grade']= 'A'
print(student)
# Out:
# {'name': 'Ash', 'age': 25, 'grade': 'A'}

# %%
student['name'] = 'Ashi'
print(student)
# Out:
# {'name': 'Ashi', 'age': 25, 'grade': 'A'}

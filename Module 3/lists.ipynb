# %%
numbers = [1,9, 5, 7, 4, 8]

# %%
numbers
# Out:
# [1, 9, 5, 7, 4, 8]

# %%
len(numbers)
# Out:
# 6

# %%
numbers[0]
# Out:
# 1

# %%
numbers[5]
# Out:
# 8

# %%
numbers[-1]
# Out:
# 8

# %%
numbers[-2]
# Out:
# 4

# %%
numbers.append(20)

# %%
numbers
# Out:
# [1, 9, 5, 7, 4, 8, 20]

# %%
len(numbers)
# Out:
# 7

# %%
numbers.remove(7)

# %%
numbers
# Out:
# [1, 9, 5, 4, 8, 20]

# %%
numbers.sort()

# %%
numbers
# Out:
# [1, 4, 5, 8, 9, 20]

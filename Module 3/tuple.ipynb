# %%
my_tuple = (6,10,12)

# %%
print(my_tuple)
# Out:
# (6, 10, 12)

# %%
print(my_tuple[0])
# Out:
# 6

# %%
len(my_tuple)
# Out:
# 3

# %%
my_tuple[3] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 my_tuple[3] = 5
#
# TypeError: 'tuple' object does not support item assignment

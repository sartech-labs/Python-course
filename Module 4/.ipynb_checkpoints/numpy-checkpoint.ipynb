# %%
import numpy as np

# %%
arr = np.array([10, 20, 30, 40, 50])

# %%
print(arr)
# Out:
# [10 20 30 40 50]

# %%
print("length", arr.size)
# Out:
# length 5

# %%
print("shape", arr.shape)
# Out:
# shape (5,)

# %%
print("data type", arr.dtype)
# Out:
# data type int64

# %%
print(arr[0])
# Out:
# 10

# %%
print(arr[-1])
# Out:
# 50

# %%
print(arr[1:4])
# Out:
# [20 30 40]

# %%
print(arr * 2)
# Out:
# [ 20  40  60  80 100]

# %%
print(arr /2)
# Out:
# [ 5. 10. 15. 20. 25.]

# %%
print(np.max(arr))
# Out:
# 50

# %%
print(np.min(arr))
# Out:
# 10

# %%
print(np.sum(arr))
# Out:
# 150

# %%
print(np.mean(arr))
# Out:
# 30.0

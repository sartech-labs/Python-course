# %%
def greet(name):
    return f'Hi {name}'

# %%
greet('Ashida')
# Out:
# 'Hi Ashida'

# %%
greet('Bob')
# Out:
# 'Hi Bob'

# %%
name = input('Enter name')
greet(name)
# Out:
# Enter name Alice
# 'Hi Alice'

# %%
mark = 65

# %%
if (mark>40):
    print('Pass')
else:
    print('Fail')
# Out:
# Fail

# %%
if(mark>90):
    print('Excellent')
elif mark>80:
    print('Good')
elif mark>40:
    print('pass')
else:
    print('Fail')
# Out:
# pass

# %%
name = 'Alice'

# %%
age = 18

# %%
height = 5.5

# %%
is_student = True

# %%
print(f'Name: {name}')
print(f'Age: {age}')
print(f'Height: {height}')
print(f'Is a student? {is_student}')
# Out:
# Name: Alice
# Age: 18
# Height: 5.5
# Is a student? True

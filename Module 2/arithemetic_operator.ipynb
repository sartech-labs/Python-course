# %%
a = 10
b = 3

# %%
print(f'Sum = {a+b}')
# Out:
# Sum = 13

# %%
print(f'a-b = {a-b}')
# Out:
# a-b = 7

# %%
print(f'a*b = {a*b}')
# Out:
# a*b = 30

# %%
print(f'a/b= {a/b}')
# Out:
# a/b= 3.3333333333333335

# %%
print(f'a%b = {a%b}')
# Out:
# a%b = 1

# %%
print(f'a**b = {a**b}')
# Out:
# a**b = 1000
